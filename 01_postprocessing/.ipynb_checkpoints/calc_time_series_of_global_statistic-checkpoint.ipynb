# %% [markdown]
# # Compute the global time series

# %%
print('Loading packages...')
import sys
sys.path.append('../00_modules/.')
from import_packages import PackageGetter
globals().update(PackageGetter.import_standard_packages_for_analysis_and_plotting())
globals().update(PackageGetter.import_custom_packages())
# Out:
# Loading packages...

# %% [markdown]
# ## 0) define functions

# %%
def calc_global_stat(da, area_weights, stat, mask=None, dims=None):
    if stat == 'mean':
        da_stat = Operator.calc_spatial_mean(da, area_weights, mask=mask, dims=dims)
    elif stat == 'integral':
        da_stat = Operator.calc_spatial_integral(da, area_weights, mask=mask, dims=dims)
    return da_stat

def get_grabber(model):
    if model == 'IPSL-CM6-ESMCO2':
        mgrab = IPSLgrabber
    return mgrab

# %% [markdown]
# ## 1) get the varias, models and runs over which to do computation

# %%
stat = 'mean'#'mean'
freq_input = 'monthly'#, 'yearly', 'daily'] #freq_output = 'monthly'#, 'yearly', 'daily', 'climatology', None]
varias = ['tas']
models = ['IPSL-CM6-ESMCO2']
runs = pruns.get_run_list('tipmip_tier1')

# %% [markdown]
# ## 2) loop over models and runs to do the computation and saving

# %%
for varia in varias:
    for model in models:
        
        global_stats = dict()
        for run in runs:
            print(f'Processing data for {varia}, {model}, {run}...')
            
            # first get the dataset
            mgrab = get_grabber(model)
            da = mgrab.get_data(varia,run,freq_input='monthly',verbose_level=0)
            print(f'... loading {da.time.size} data points in time.')

            # get the area_weights
            print(f'... getting area weights.')
            area_weights = mgrab.get_area(varia,freq_input)

            # which region do i want to cover
            print(f'... getting a regional mask.') 
            
            # then do the spatial statistic
            print(f'... compute statistic')
            global_stat = calc_global_stat(da, area_weights, stat, mask=None, dims=None)
            global_stats[run] = global_stat

            # save the data
            save_string = f'{varia}_{model}_{run}_global_{stat}.nc'
            print(f'... saving under {save_string}')
            print(' ')
# Out:
# Processing data for tas, IPSL-CM6-ESMCO2, esm-piControl...
# ... loading 7800 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-piControl_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0...
# ... loading 7080 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0-gwl2p0...
# ... loading 3600 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0-gwl2p0_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0-gwl4p0...
# ... loading 3600 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0-gwl4p0_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0-gwl2p0-50y-dn2p0...
# ... loading 1680 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0-gwl2p0-50y-dn2p0_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0-gwl4p0-50y-dn2p0...
# ... loading 3000 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0-gwl4p0-50y-dn2p0_global_mean.nc
#
# Processing data for tas, IPSL-CM6-ESMCO2, esm-up2p0-gwl4p0-50y-dn2p0-gwl2p0...
# ... loading 2400 data points in time.
# ... getting area weights.
# ... getting a regional mask.
# ... compute statistic
# ... saving under tas_IPSL-CM6-ESMCO2_esm-up2p0-gwl4p0-50y-dn2p0-gwl2p0_global_mean.nc

# %% [markdown]
# ## 3) Plot the time series

# %%
for key in global_stats.keys():
    print(f'... plotting {key} ...')
    global_stats[key].plot()
plt.show()
# Out:
# ... plotting esm-piControl ...
# ... plotting esm-up2p0 ...
# ... plotting esm-up2p0-gwl2p0 ...
# ... plotting esm-up2p0-gwl4p0 ...
# ... plotting esm-up2p0-gwl2p0-50y-dn2p0 ...
# ... plotting esm-up2p0-gwl4p0-50y-dn2p0 ...
# ... plotting esm-up2p0-gwl4p0-50y-dn2p0-gwl2p0 ...
